# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"15396433957","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":921901248,"name":"kazi-org/kazi","url":"https://api.github.com/repos/kazi-org/kazi"},"payload":{"repository_id":921901248,"push_id":37687463613,"ref":"refs/heads/release-please--branches--main","head":"63551c176a7d2f09fdc6110f3bad011791dfd62d","before":"590a9697a81e9092f1d233f83685ce411cab4b0f"},"public":true,"created_at":"2026-07-20T19:41:42Z","org":{"id":196381658,"login":"kazi-org","gravatar_id":"","url":"https://api.github.com/orgs/kazi-org","avatar_url":"https://avatars.githubusercontent.com/u/196381658?"}},{"id":"15396433943","type":"PushEvent","actor":{"id":306645198,"login":"ayela1427","display_login":"ayela1427","gravatar_id":"","url":"https://api.github.com/users/ayela1427","avatar_url":"https://ava
# ...

# %%
r.json()
# Out:
# [{'id': '15396433957',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 921901248,
#    'name': 'kazi-org/kazi',
#    'url': 'https://api.github.com/repos/kazi-org/kazi'},
#   'payload': {'repository_id': 921901248,
#    'push_id': 37687463613,
#    'ref': 'refs/heads/release-please--branches--main',
#    'head': '63551c176a7d2f09fdc6110f3bad011791dfd62d',
#    'before': '590a9697a81e9092f1d233f83685ce411cab4b0f'},
#   'public': True,
#   'created_at': '2026-07-20T19:41:42Z',
#   'org': {'id': 196381658,
#    'login': 'kazi-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kazi-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/196381658?'}},
#  {'id': '15396433943',
# ...

# %%
f = requests.get('https://api.github.com/versions')
f.status_code
# Out:
# 200

# %%
f.json()
# Out:
# ['2026-03-10', '2022-11-28']

# %%
f.raise_for_status()
